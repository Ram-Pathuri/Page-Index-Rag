# %%
import pandas as pd
import os

# %%
print("Testing the resources")
# C:\Users\ADMIN\Text2cad>C:/Users/ADMIN/miniconda3/Scripts/activate(base) C:\Users\ADMIN\Text2cad>conda activate pyoccenv
# Out:
# Testing the resources
